# %% [markdown]
# <a href="https://colab.research.google.com/github/Amruthnayak2406/Road-accident-analysis/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_excel("/content/Road Accident Data.xlsx")

# %%
data.head(10)
# Out:
#   Accident_Index Accident Date Day_of_Week          Junction_Control  \
# 0      BS0000001    2021-01-01    Thursday  Give way or uncontrolled
# 1      BS0000002    2021-01-05      Monday  Give way or uncontrolled
# 2      BS0000003    2021-01-04      Sunday  Give way or uncontrolled
# 3      BS0000004    2021-01-05      Monday       Auto traffic signal
# 4      BS0000005    2021-01-06     Tuesday       Auto traffic signal
# 5      BS0000006    2021-01-01    Thursday  Give way or uncontrolled
# 6      BS0000007    2021-01-08    Thursday  Give way or uncontrolled
# 7      BS0000008    2021-01-02      Friday       Auto traffic signal
# 8      BS0000009    2021-01-07   Wednesday  Give way or uncontrolled
# 9      BS0000010    2021-01-10    Saturday       Auto traffic signal
#
#            Junction_Detail Accident_Severity   Latitude  \
# 0  T or staggered junction           Serious  51.512273
# 1               Crossroads           Serious  51.514399
# ...

# %%
data.columns
# Out:
# Index(['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control',
#        'Junction_Detail', 'Accident_Severity', 'Latitude', 'Light_Conditions',
#        'Local_Authority_(District)', 'Carriageway_Hazards', 'Longitude',
#        'Number_of_Casualties', 'Number_of_Vehicles', 'Police_Force',
#        'Road_Surface_Conditions', 'Road_Type', 'Speed_limit', 'Time',
#        'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type'],
#       dtype='object')

# %%
data.isna()
# Out:
#         Accident_Index  Accident Date  Day_of_Week  Junction_Control  \
# 0                False          False        False             False
# 1                False          False        False             False
# 2                False          False        False             False
# 3                False          False        False             False
# 4                False          False        False             False
# ...                ...            ...          ...               ...
# 307968           False          False        False             False
# 307969           False          False        False             False
# 307970           False          False        False             False
# 307971           False          False        False             False
# 307972           False          False        False             False
#
#         Junction_Detail  Accident_Severity  Latitude  Light_Conditions  \
# ...

# %%
data.isna().any()
# Out:
# Accident_Index                False
# Accident Date                 False
# Day_of_Week                   False
# Junction_Control              False
# Junction_Detail               False
# Accident_Severity             False
# Latitude                      False
# Light_Conditions              False
# Local_Authority_(District)    False
# Carriageway_Hazards            True
# Longitude                     False
# Number_of_Casualties          False
# Number_of_Vehicles            False
# Police_Force                  False
# Road_Surface_Conditions       False
# Road_Type                     False
# Speed_limit                   False
# Time                           True
# Urban_or_Rural_Area           False
# Weather_Conditions            False
# Vehicle_Type                  False
# dtype: bool

# %%
data.fillna(0, inplace=True)

# %%
data.isna().any()
# Out:
# Accident_Index                False
# Accident Date                 False
# Day_of_Week                   False
# Junction_Control              False
# Junction_Detail               False
# Accident_Severity             False
# Latitude                      False
# Light_Conditions              False
# Local_Authority_(District)    False
# Carriageway_Hazards           False
# Longitude                     False
# Number_of_Casualties          False
# Number_of_Vehicles            False
# Police_Force                  False
# Road_Surface_Conditions       False
# Road_Type                     False
# Speed_limit                   False
# Time                          False
# Urban_or_Rural_Area           False
# Weather_Conditions            False
# Vehicle_Type                  False
# dtype: bool

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles  \
# count  307973.000000  307973.000000         307973.000000       307973.000000
# mean       52.487005      -1.368884              1.356882            1.829063
# std         1.339011       1.356092              0.815857            0.710477
# min        49.914488      -7.516225              1.000000            1.000000
# 25%        51.485248      -2.247937              1.000000            1.000000
# 50%        52.225943      -1.349258              1.000000            2.000000
# 75%        53.415517      -0.206810              1.000000            2.000000
# max        60.598055       1.759398             48.000000           32.000000
#
#          Speed_limit
# count  307973.000000
# mean       38.866037
# std        14.032933
# min        10.000000
# 25%        30.000000
# 50%        30.000000
# 75%        50.000000
# max        70.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307973 entries, 0 to 307972
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident_Index              307973 non-null  object
#  1   Accident Date               307973 non-null  datetime64[ns]
#  2   Day_of_Week                 307973 non-null  object
#  3   Junction_Control            307973 non-null  object
#  4   Junction_Detail             307973 non-null  object
#  5   Accident_Severity           307973 non-null  object
#  6   Latitude                    307973 non-null  float64
#  7   Light_Conditions            307973 non-null  object
#  8   Local_Authority_(District)  307973 non-null  object
#  9   Carriageway_Hazards         307973 non-null  object
#  10  Longitude                   307973 non-null  float64
#  11  Number_of_Casualties        307973 non-null  int64
# ...

# %%
plt.bar(data['Vehicle_Type'],data['Number_of_Casualties'] )
plt.xlabel('Vehicle_Type')
plt.ylabel('Number_of_Casualties')
plt.title('No of casualties wrt vehicles')
plt.show()

# %%
plt.bar(data['Urban_or_Rural_Area'],data['Number_of_Casualties'] )
plt.xlabel('Urban_or_Rural_Area')
plt.ylabel('Number_of_Casualties')
plt.title('No of casualties in Urban and Rural')
plt.show()

# %%
plt.bar(data['Road_Surface_Conditions'],data['Number_of_Casualties'] )
plt.xlabel('Road_Surface_Conditions')
plt.ylabel('Number_of_Casualties')
plt.title('No of casualties based on road surface')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.pie(data["Accident_Severity"].value_counts(),autopct="%1.1f%%",labels=np.unique(data["Accident_Severity"]))
plt.title("Accident Severity")
plt.legend(title="Accident types", loc="center left", bbox_to_anchor=(1,0.5))
plt.axis("equal")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.pie(data["Day_of_Week"].value_counts(),autopct="%1.1f%%",labels=np.unique(data["Day_of_Week"]))
plt.title("Accident day of week")
plt.legend(title="Accident types", loc="center left", bbox_to_anchor=(1,0.5))
plt.axis("equal")
plt.show()

# %%
plt.figure(figsize=(11,6))
plt.pie(data["Light_Conditions"].value_counts(),autopct="%1.1f%%",labels=np.unique(data["Light_Conditions"]))
plt.title("Light condition")
plt.legend(title="Accident types", loc="center left", bbox_to_anchor=(1,0.5))
plt.axis("equal")
plt.show()

# %%
plt.plot(data['Number_of_Vehicles'])
plt.title("No of vehicles in accident")
# Out:
# Text(0.5, 1.0, 'No of vehicles in accident')

# %%
plt.figure(figsize= (20,15))
plt.subplot(4,4,1)
sns.boxplot(data['Speed_limit'])
plt.title("Speed Limit")
# Out:
# Text(0.5, 1.0, 'Speed Limit')

# %%
sns.pairplot(data,diag_kind='kde')
